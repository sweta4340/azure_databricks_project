# %% [markdown]
# ![image_1773263670264.png](./image_1773263670264.png "image_1773263670264.png")

# %% [markdown]
# ![image_1773263693269.png](./image_1773263693269.png "image_1773263693269.png")

# %% [markdown]
# ![image_1773263724096.png](./image_1773263724096.png "image_1773263724096.png")

# %%
# %sql
SELECT * FROM circuitbox.lakehouse.silver_orders

# %%
# %sql
select * from `system`.`access`.`table_lineage`
