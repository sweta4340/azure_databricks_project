# %%
df = spark.read.format('csv').options(header='true', delimiter='\t').load('/Volumes/gizmobox/landing/operational_data/addresses/')
display(df)

# %%
df.writeTo('gizmobox.bronze.py_addresses').createOrReplace()
