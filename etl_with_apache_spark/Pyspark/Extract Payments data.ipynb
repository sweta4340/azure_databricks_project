# %% [markdown]
# Create schema using ddl

# %%
payments_schema = 'payment_id INTEGER, order_id INTEGER, payment_timestamp TIMESTAMP, payment_status INTEGER, payment_method STRING'
df = spark.read.format('csv').schema(payments_schema).option('header', 'true').load('abfss://gizmobox@databricksextstorageacc.dfs.core.windows.net/landing/external_data/payments')

# %%
username = spark.sql('SELECT current_user()').collect()[0][0]
print(username)

# %%
# %sql
GRANT READ FILES ON EXTERNAL LOCATION databricks_external_loc_gizmobox TO `sweta.patel30380@gmail.com`;

# %%
display(df)
