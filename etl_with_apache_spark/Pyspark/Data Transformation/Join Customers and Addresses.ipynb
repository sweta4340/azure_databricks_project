# %%
df_customer = spark.table('gizmobox.silver.py_customers')
df_addresses = spark.table('gizmobox.silver.py_addresses')

# %%
final_df = df_customer.join(df_addresses, 'customer_id', how='inner')
display(final_df)

# %%
final_df.writeTo('gizmobox.gold.py_customer_address').createOrReplace()
